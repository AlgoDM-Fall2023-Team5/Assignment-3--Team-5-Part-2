# %% [markdown]
# # Image Search Based on a Natural Language Query Using CLIP Model
#
# In this notebook, we implement a simople image search solution based on a natural language query using the CLIP model [1]. We use CLIP to pre-calculate embeddigns for images in a collection. For a given query, we calculate its embedding using CLIP and then search for the nearest neighbors in the collection of image embeddigns.
#
# The implementation is based on [2].
#
# ### References
#   1. https://openai.com/blog/clip/#rf33
#   2. https://github.com/haltakov/natural-language-image-search
#
# ### Data
# We use a small image collection available in the `tensorhouse-data` repository (`tensor-house-data/search/unspash-small`).

# %% [markdown]
# ## Load the CLIP Model

# %%
import clip
import torch
import math
import numpy as np
import pandas as pd

from PIL import Image
import shutil
import os

import matplotlib.pyplot as plt
plt.rcParams.update({'pdf.fonttype': 'truetype'})
from mpl_toolkits.axes_grid1 import ImageGrid

# %% [markdown]
# ## Load CLIP Model

# %%
#
# Load the open CLIP model
#
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)

# %% [markdown]
# ## Process Input Images and Save Features

# %%
from pathlib import Path

# Set the path to the images
images_path = Path('/workspaces/Assignment-3--Team-5-Part-2/clothing-dataset-master/images')

# List all JPGs in the folder
images_files = list(images_path.glob('*.jpg'))

# Print some statistics
print(f'Images found: {len(images_files)}')

# Display images
rows, columns = (4, 4)
fig = plt.figure(figsize=(10, 10))
grid = ImageGrid(fig, 111,  
                 nrows_ncols=(rows, columns),  
                 axes_pad=0.1,  
                 )

for ax, im in zip(grid, images_files[:rows*columns]):
    ax.imshow(Image.open(im))
    ax.axis('off')
plt.show()
# Out:
# Images found: 5756

# %%
#
# Path where the feature vectors will be stored
#
features_path = Path(".") / "features"
if os.path.exists(features_path):
    shutil.rmtree(features_path)
os.makedirs(features_path)

# Function that computes the feature vectors for a batch of images
def compute_clip_features(images_batch):
    # Load all the images from the files
    images = [Image.open(image_file) for image_file in images_batch]
    
    # Preprocess all images
    images_preprocessed = torch.stack([preprocess(image) for image in images]).to(device)

    with torch.no_grad():
        # Encode the images batch to compute the feature vectors and normalize them
        images_features = model.encode_image(images_preprocessed)
        images_features /= images_features.norm(dim=-1, keepdim=True)

    # Transfer the feature vectors back to the CPU and convert to numpy
    return images_features.cpu().numpy()

# Define the batch size
batch_size = 16


# Compute how many batches are needed
batches = math.ceil(len(images_files) / batch_size)

#
# Process each batch
#
for i in range(batches):
    print(f"Processing batch {i+1}/{batches}")

    batch_ids_path = features_path / f"{i:010d}.csv"
    batch_features_path = features_path / f"{i:010d}.npy"
    
    # Only do the processing if the batch wasn't processed yet
    if not batch_features_path.exists():
        try:
            # Select the images for the current batch
            batch_files = images_files[i*batch_size : (i+1)*batch_size]

            # Compute the features and save to a numpy file
            batch_features = compute_clip_features(batch_files)
            np.save(batch_features_path, batch_features)

            # Save the image IDs to a CSV file
            image_ids = [image_file.name.split(".")[0] for image_file in batch_files]
            image_ids_data = pd.DataFrame(image_ids, columns=['image_id'])
            image_ids_data.to_csv(batch_ids_path, index=False)
        except Exception as e:
            # Catch problems with the processing to make the process more robust
            print(f'Problem with batch {i} {e}')
# Out:
# Processing batch 1/360
# Processing batch 2/360
# Processing batch 3/360
# Processing batch 4/360
# Processing batch 5/360
# Processing batch 6/360
# Processing batch 7/360
# Processing batch 8/360
# Processing batch 9/360
# Processing batch 10/360
# Processing batch 11/360
# Processing batch 12/360
# Processing batch 13/360
# Processing batch 14/360
# Processing batch 15/360
# Processing batch 16/360
# Processing batch 17/360
# Processing batch 18/360
# Processing batch 19/360
# Processing batch 20/360
# Processing batch 21/360
# Processing batch 22/360
# Processing batch 23/360
# Processing batch 24/360
# Processing batch 25/360
# Processing batch 26/360
# Processing batch 27/360
# Processing batch 28/360
# Processing batch 29/360
# Processing batch 30/360
# Processing batch 31/360
# Processing batch 32/360
# Processing batch 33/360
# Processing batch 34/360
# Processing batch 35/360
# Processing batch 36/360
# Processing batch 37/360
# Processing batch 38/360
# Processing batch 39/360
# Processing batch 40/360
# Processing batch 41/360
# Processing batch 42/360
# Processing batch 43/360
# Processing batch 44/360
# Processing batch 45/360
# Processing batch 46/360
# Processing batch 47/360
# Processing batch 48/360
# Processing batch 49/360
# Processing batch 50/360
# Processing batch 51/360
# Processing batch 52/360
# Processing batch 53/360
# Processing batch 54/360
# Processing batch 55/360
# Processing batch 56/360
# Processing batch 57/360
# Processing batch 58/360
# Processing batch 59/360
# Processing batch 60/360
# Processing batch 61/360
# Processing batch 62/360
# Processing batch 63/360
# Processing batch 64/360
# Processing batch 65/360
# Processing batch 66/360
# Processing batch 67/360
# Processing batch 68/360
# Processing batch 69/360
# Processing batch 70/360
# Processing batch 71/360
# Processing batch 72/360
# Processing batch 73/360
# Processing batch 74/360
# Processing batch 75/360
# Processing batch 76/360
# Processing batch 77/360
# Processing batch 78/360
# Processing batch 79/360
# Processing batch 80/360
# Processing batch 81/360
# Processing batch 82/360
# Processing batch 83/360
# Processing batch 84/360
# Processing batch 85/360
# Processing batch 86/360
# Processing batch 87/360
# Processing batch 88/360
# Processing batch 89/360
# Processing batch 90/360
# Processing batch 91/360
# Processing batch 92/360
# Processing batch 93/360
# Processing batch 94/360
# Processing batch 95/360
# Processing batch 96/360
# Processing batch 97/360
# Processing batch 98/360
# Processing batch 99/360
# Processing batch 100/360
# Processing batch 101/360
# Processing batch 102/360
# Processing batch 103/360
# Processing batch 104/360
# Processing batch 105/360
# Processing batch 106/360
# Processing batch 107/360
# Processing batch 108/360
# Processing batch 109/360
# Processing batch 110/360
# Processing batch 111/360
# Processing batch 112/360
# Processing batch 113/360
# Processing batch 114/360
# Processing batch 115/360
# Processing batch 116/360
# Processing batch 117/360
# Processing batch 118/360
# Processing batch 119/360
# Processing batch 120/360
# Processing batch 121/360
# Processing batch 122/360
# Processing batch 123/360
# Processing batch 124/360
# Processing batch 125/360
# Processing batch 126/360
# Processing batch 127/360
# Processing batch 128/360
# Processing batch 129/360
# Processing batch 130/360
# Processing batch 131/360
# Processing batch 132/360
# Processing batch 133/360
# Processing batch 134/360
# Processing batch 135/360
# Processing batch 136/360
# Processing batch 137/360
# Processing batch 138/360
# Processing batch 139/360
# Processing batch 140/360
# Processing batch 141/360
# Processing batch 142/360
# Processing batch 143/360
# Processing batch 144/360
# Processing batch 145/360
# Processing batch 146/360
# Processing batch 147/360
# Processing batch 148/360
# Processing batch 149/360
# Processing batch 150/360
# Processing batch 151/360
# Processing batch 152/360
# Processing batch 153/360
# Processing batch 154/360
# Processing batch 155/360
# Processing batch 156/360
# Processing batch 157/360
# Processing batch 158/360
# Processing batch 159/360
# Processing batch 160/360
# Processing batch 161/360
# Processing batch 162/360
# Processing batch 163/360
# Processing batch 164/360
# Processing batch 165/360
# Processing batch 166/360
# Processing batch 167/360
# Processing batch 168/360
# Processing batch 169/360
# Processing batch 170/360
# Processing batch 171/360
# Processing batch 172/360
# Processing batch 173/360
# Processing batch 174/360
# Processing batch 175/360
# Processing batch 176/360
# Processing batch 177/360
# Processing batch 178/360
# Processing batch 179/360
# Processing batch 180/360
# Processing batch 181/360
# Processing batch 182/360
# Processing batch 183/360
# Processing batch 184/360
# Processing batch 185/360
# Processing batch 186/360
# Processing batch 187/360
# Processing batch 188/360
# Processing batch 189/360
# Processing batch 190/360
# Processing batch 191/360
# Processing batch 192/360
# Processing batch 193/360
# Processing batch 194/360
# Processing batch 195/360
# Processing batch 196/360
# Processing batch 197/360
# Processing batch 198/360
# Processing batch 199/360
# Processing batch 200/360
# Processing batch 201/360
# Processing batch 202/360
# Processing batch 203/360
# Processing batch 204/360
# Processing batch 205/360
# Processing batch 206/360
# Processing batch 207/360
# Processing batch 208/360
# Processing batch 209/360
# Processing batch 210/360
# Processing batch 211/360
# Processing batch 212/360
# Processing batch 213/360
# Processing batch 214/360
# Processing batch 215/360
# Processing batch 216/360
# Processing batch 217/360
# Processing batch 218/360
# Processing batch 219/360
# Processing batch 220/360
# Processing batch 221/360
# Processing batch 222/360
# Processing batch 223/360
# Processing batch 224/360
# Processing batch 225/360
# Processing batch 226/360
# Processing batch 227/360
# Processing batch 228/360
# Processing batch 229/360
# Processing batch 230/360
# Processing batch 231/360
# Processing batch 232/360
# Processing batch 233/360
# Processing batch 234/360
# Processing batch 235/360
# Processing batch 236/360
# Processing batch 237/360
# Processing batch 238/360
# Processing batch 239/360
# Processing batch 240/360
# Processing batch 241/360
# Processing batch 242/360
# Processing batch 243/360
# Processing batch 244/360
# Processing batch 245/360
# Processing batch 246/360
# Processing batch 247/360
# Processing batch 248/360
# Processing batch 249/360
# Processing batch 250/360
# Processing batch 251/360
# Processing batch 252/360
# Processing batch 253/360
# Processing batch 254/360
# Processing batch 255/360
# Processing batch 256/360
# Processing batch 257/360
# Processing batch 258/360
# Processing batch 259/360
# Processing batch 260/360
# Processing batch 261/360
# Processing batch 262/360
# Processing batch 263/360
# Processing batch 264/360
# Processing batch 265/360
# Processing batch 266/360
# Processing batch 267/360
# Processing batch 268/360
# Processing batch 269/360
# Processing batch 270/360
# Processing batch 271/360
# Processing batch 272/360
# Processing batch 273/360
# Processing batch 274/360
# Processing batch 275/360
# Processing batch 276/360
# Processing batch 277/360
# Processing batch 278/360
# Processing batch 279/360
# Processing batch 280/360
# Processing batch 281/360
# Processing batch 282/360
# Processing batch 283/360
# Processing batch 284/360
# Processing batch 285/360
# Processing batch 286/360
# Processing batch 287/360
# Processing batch 288/360
# Processing batch 289/360
# Processing batch 290/360
# Processing batch 291/360
# Processing batch 292/360
# Processing batch 293/360
# Processing batch 294/360
# Processing batch 295/360
# Processing batch 296/360
# Processing batch 297/360
# Processing batch 298/360
# Processing batch 299/360
# Processing batch 300/360
# Processing batch 301/360
# Processing batch 302/360
# Processing batch 303/360
# Processing batch 304/360
# Processing batch 305/360
# Processing batch 306/360
# Processing batch 307/360
# Processing batch 308/360
# Processing batch 309/360
# Processing batch 310/360
# Processing batch 311/360
# Processing batch 312/360
# Processing batch 313/360
# Processing batch 314/360
# Processing batch 315/360
# Processing batch 316/360
# Processing batch 317/360
# Processing batch 318/360
# Processing batch 319/360
# Processing batch 320/360
# Processing batch 321/360
# Processing batch 322/360
# Processing batch 323/360
# Processing batch 324/360
# Processing batch 325/360
# Processing batch 326/360
# Processing batch 327/360
# Processing batch 328/360
# Processing batch 329/360
# Processing batch 330/360
# Processing batch 331/360
# Processing batch 332/360
# Processing batch 333/360
# Processing batch 334/360
# Processing batch 335/360
# Processing batch 336/360
# Processing batch 337/360
# Processing batch 338/360
# Processing batch 339/360
# Processing batch 340/360
# Processing batch 341/360
# Processing batch 342/360
# Processing batch 343/360
# Processing batch 344/360
# Processing batch 345/360
# Processing batch 346/360
# Processing batch 347/360
# Processing batch 348/360
# Processing batch 349/360
# Processing batch 350/360
# Processing batch 351/360
# Processing batch 352/360
# Processing batch 353/360
# Processing batch 354/360
# Processing batch 355/360
# Processing batch 356/360
# Processing batch 357/360
# Processing batch 358/360
# Processing batch 359/360
# Processing batch 360/360

# %%
# Load all numpy files
features_list = [np.load(features_file) for features_file in sorted(features_path.glob("*.npy"))]

# Concatenate the features and store in a merged file
features = np.concatenate(features_list)
np.save(features_path / "features.npy", features)

# Load all the image IDs
image_ids = pd.concat([pd.read_csv(ids_file) for ids_file in sorted(features_path.glob("*.csv"))])
image_ids.to_csv(features_path / "image_ids.csv", index=False)

# %% [markdown]
# ## Load Features

# %%
# Load the image IDs
image_ids = pd.read_csv(features_path / 'image_ids.csv')
image_ids = list(image_ids['image_id'])

# Load the features vectors
image_features = np.load(features_path / 'features.npy')

# Convert features to Tensors: Float32 on CPU and Float16 on GPU
if device == "cpu":
    image_features = torch.from_numpy(image_features).float().to(device)
else:
    image_features = torch.from_numpy(image_features).to(device)

# Print some statistics
print(f"Images loaded: {len(image_ids)}")
# Out:
# Images loaded: 5756

# %% [markdown]
# ## Search Images Based on a Text Query

# %%
def encode_search_query(search_query):
    with torch.no_grad():
        # Encode and normalize the search query using CLIP
        text_encoded = model.encode_text(clip.tokenize(search_query).to(device))
        text_encoded /= text_encoded.norm(dim=-1, keepdim=True)

    # Retrieve the feature vector
    return text_encoded

def find_best_matches(text_features, image_features, image_ids, results_count=3):
  # Compute the similarity between the search query and each image using the Cosine similarity
  similarities = (image_features @ text_features.T).squeeze(1)

  # Sort the images by their similarity score
  best_image_idx = (-similarities).argsort()

  # Return the image IDs of the best matches
  return [image_ids[i] for i in best_image_idx[:results_count]]

def search(search_query, image_features, image_ids, results_count=3):
  # Encode the search query
  text_features = encode_search_query(search_query)

  # Find the best matches
  return find_best_matches(text_features, image_features, image_ids, results_count)

#
# Search for images and visualize the results
#
search_queries = ['T shirt', 
                  'Footwear', 
                  'Jacket', 
                  'Hat',
                  'skirt',
                  'pants',
                  'tops']
n_results_per_query = 3
 
fig, ax = plt.subplots(len(search_queries), n_results_per_query + 1, figsize=(15, 10))    
for i, search_query in enumerate(search_queries):
    result_image_ids = search(search_query, image_features, image_ids, n_results_per_query)
    
    ax[i, 0].text(0.0, 0.5, search_query)
    ax[i, 0].axis('off')
    for j, image_id in enumerate(result_image_ids):
        image = Image.open(f'{images_path}/{image_id}.jpg')
        ax[i, j+1].imshow(image)
        ax[i, j+1].axis('off')
